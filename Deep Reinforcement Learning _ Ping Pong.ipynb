# %%
# !pip install gym[atari]
# !pip install autorom[accept-rom-license]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[atari] in /usr/local/lib/python3.7/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (1.21.6)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (4.13.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (1.5.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (0.0.8)
# Collecting ale-py~=0.7.5
#   Downloading ale_py-0.7.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 27.6 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from ale-py~=0.7.5->gym[atari]) (5.10.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[atari]) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[atari]) (4.1.1)
# Installing collected packages: ale-py
# Successfully installed ale-py-0.7.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autorom[accept-rom-license]
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]) (4.64.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]) (5.10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]) (2.23.0)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.4.2.tar.gz (9.8 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->autorom[accept-rom-license]) (3.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]) (2.10)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (PEP 517) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.4.2-py3-none-any.whl size=441027 sha256=d489b1d831758ead08c1ac4f4a9c11e6fa64a6ab394c821e89455b85d6a3ef8d
#   Stored in directory: /root/.cache/pip/wheels/87/67/2e/6147e7912fe37f5408b80d07527dab807c1d25f5c403a9538a
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.4.2 autorom-0.4.2

# %%
import numpy as np
import pickle
import gym

from gym.wrappers.record_video import RecordVideo
import warnings
warnings.filterwarnings('ignore')

# %%
# hyperparameters to tune
H = 200 # number of hidden layer neurons
batch_size = 10 # used to perform a RMS prop param update every batch_size steps
learning_rate = 1e-3 # learning rate used in RMS prop
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2

# Config flags - video output and res
resume = False # resume training from previous checkpoint (from save.p  file)?
render = True # render video output?

# model initialization
D = 75 * 80 # input dimensionality: 75x80 grid
if resume:
  model = pickle.load(open('save.p', 'rb'))
else:
  model = {}
  model['W1'] = np.random.randn(H,D) / np.sqrt(D) # "Xavier" initialization - Shape will be H x D
  model['W2'] = np.random.randn(H) / np.sqrt(H) # Shape will be H

grad_buffer = { k : np.zeros_like(v) for k,v in model.items() } # update buffers that add up gradients over a batch
rmsprop_cache = { k : np.zeros_like(v) for k,v in model.items() } # rmsprop memory

# %%
def sigmoid(x):
  return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

def prepro(I):
  """ prepro 210x160x3 uint8 frame into 6000 (75x80) 1D float vector """
  I = I[35:185] # crop - remove 35px from start & 25px from end of image in x, to reduce redundant parts of image (i.e. after ball passes paddle)
  I = I[::2,::2,0] # downsample by factor of 2.
  I[I == 144] = 0 # erase background (background type 1)
  I[I == 109] = 0 # erase background (background type 2)
  I[I != 0] = 1 # everything else (paddles, ball) just set to 1. this makes the image grayscale effectively
  return I.astype(float).ravel() # ravel flattens an array and collapses it into a column vector

def discount_rewards(r):
  """ take 1D float array of rewards and compute discounted reward """
  """ this function discounts from the action closest to the end of the completed game backwards
  so that the most recent action has a greater weight """
  discounted_r = np.zeros_like(r)
  running_add = 0
  for t in reversed(range(0, r.size)): # xrange is no longer supported in Python 3
    if r[t] != 0: running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
    running_add = running_add * gamma + r[t]
    discounted_r[t] = running_add
  return discounted_r
def policy_forward(x):
  """This is a manual implementation of a forward prop"""
  h = np.dot(model['W1'], x) # (H x D) . (D x 1) = (H x 1) (200 x 1)
  h[h<0] = 0 # ReLU introduces non-linearity
  logp = np.dot(model['W2'], h) # This is a logits function and outputs a decimal.   (1 x H) . (H x 1) = 1 (scalar)
  p = sigmoid(logp)  # squashes output to  between 0 & 1 range
  return p, h # return probability of taking action 2 (UP), and hidden state

def policy_backward(eph, epx, epdlogp):
  """ backward pass. (eph is array of intermediate hidden states) """
  """ Manual implementation of a backward prop"""
  """ It takes an array of the hidden states that corresponds to all the images that were
  fed to the NN (for the entire episode, so a bunch of games) and their corresponding logp"""
  dW2 = np.dot(eph.T, epdlogp).ravel()
  dh = np.outer(epdlogp, model['W2'])
  dh[eph <= 0] = 0 # backpro prelu
  dW1 = np.dot(dh.T, epx)
  return {'W1':dW1, 'W2':dW2}

# %%
env = gym.make("Pong-v4")
env = RecordVideo(env, '/content/drive/MyDrive/pongvideo', episode_trigger = lambda episode_number: True) # record the game as as an mp4 file
observation = env.reset()
prev_x = None # used in computing the difference frame
xs,hs,dlogps,drs = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 0
while True:
  if render: env.render()

  # preprocess the observation, set input to network to be difference image
  cur_x = prepro(observation)
  # we take the difference in the pixel input, since this is more likely to account for interesting information
  # e.g. motion
  x = cur_x - prev_x if prev_x is not None else np.zeros(D)
  prev_x = cur_x

  # forward the policy network and sample an action from the returned probability
  aprob, h = policy_forward(x)
  # The following step is randomly choosing a number which is the basis of making an action decision
  # If the random number is less than the probability of UP output from our neural network given the image
  # then go down.  The randomness introduces 'exploration' of the Agent
  action = 2 if np.random.uniform() < aprob else 3 # roll the dice! 2 is UP, 3 is DOWN, 0 is stay the same

  # record various intermediates (needed later for backprop).
  # This code would have otherwise been handled by a NN library
  xs.append(x) # observation
  hs.append(h) # hidden state
  y = 1 if action == 2 else 0 # a "fake label" - this is the label that we're passing to the neural network
  # to fake labels for supervised learning. It's fake because it is generated algorithmically, and not based
  # on a ground truth, as is typically the case for Supervised learning

  dlogps.append(y - aprob) # grad that encourages the action that was taken to be taken (see http://cs231n.github.io/neural-networks-2/#losses if confused)

  # step the environment and get new measurements
  observation, reward, done, info = env.step(action)
  reward_sum += reward
  drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

  if done: # an episode finished
    episode_number += 1

    # stack together all inputs, hidden states, action gradients, and rewards for this episode
    epx = np.vstack(xs)
    eph = np.vstack(hs)
    epdlogp = np.vstack(dlogps)
    epr = np.vstack(drs)
    xs,hs,dlogps,drs = [],[],[],[] # reset array memory

    # compute the discounted reward backwards through time
    discounted_epr = discount_rewards(epr)
    # standardize the rewards to be unit normal (helps control the gradient estimator variance)
    discounted_epr -= np.mean(discounted_epr)
    discounted_epr /= np.std(discounted_epr)

    epdlogp *= discounted_epr # modulate the gradient with advantage (Policy Grad magic happens right here.)
    grad = policy_backward(eph, epx, epdlogp)
    for k in model: grad_buffer[k] += grad[k] # accumulate grad over batch

    # perform rmsprop parameter update every batch_size episodes
    if episode_number % batch_size == 0:
      for k,v in model.items():
        g = grad_buffer[k] # gradient
        rmsprop_cache[k] = decay_rate * rmsprop_cache[k] + (1 - decay_rate) * g**2
        model[k] += learning_rate * g / (np.sqrt(rmsprop_cache[k]) + 1e-5)
        grad_buffer[k] = np.zeros_like(v) # reset batch gradient buffer

    # boring book-keeping
    running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
    print ('resetting env. episode reward total was %f. running mean: %f' % (reward_sum, running_reward))
    if episode_number % 100 == 0: pickle.dump(model, open('save.p', 'wb'))
    reward_sum = 0
    observation = env.reset() # reset env
    prev_x = None

  if reward != 0: # Pong has either +1 or -1 reward exactly when game ends.
    print ('ep %d: game finished, reward: %f' % (episode_number, reward) + ('' if reward == -1 else  '!!!!!!!!'))
# Out:
# ep 952: game finished, reward: 1.000000!!!!!!!!
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: 1.000000!!!!!!!!
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: 1.000000!!!!!!!!
# ep 952: game finished, reward: -1.000000
# ep 952: game finished, reward: -1.000000
# resetting env. episode reward total was -18.000000. running mean: -17.032764
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: 1.000000!!!!!!!!
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: 1.000000!!!!!!!!
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: 1.000000!!!!!!!!
# ep 953: game finished, reward: 1.000000!!!!!!!!
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: 1.000000!!!!!!!!
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: 1.000000!!!!!!!!
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: 1.000000!!!!!!!!
# ep 953: game finished, reward: -1.000000
# ep 953: game finished, reward: 1.000000!!!!!!!!
# ep 953: game finished, reward: 1.000000!!!!!!!!
# ep 953: game finished, reward: -1.000000
# resetting env. episode reward total was -12.000000. running mean: -16.982436
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: 1.000000!!!!!!!!
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: 1.000000!!!!!!!!
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: 1.000000!!!!!!!!
# ep 954: game finished, reward: -1.000000
# ep 954: game finished, reward: -1.000000
# resetting env. episode reward total was -18.000000. running mean: -16.992612
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: 1.000000!!!!!!!!
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: 1.000000!!!!!!!!
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: 1.000000!!!!!!!!
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: 1.000000!!!!!!!!
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: 1.000000!!!!!!!!
# ep 955: game finished, reward: 1.000000!!!!!!!!
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: 1.000000!!!!!!!!
# ep 955: game finished, reward: -1.000000
# ep 955: game finished, reward: 1.000000!!!!!!!!
# ep 955: game finished, reward: -1.000000
# resetting env. episode reward total was -13.000000. running mean: -16.952686
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: 1.000000!!!!!!!!
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: 1.000000!!!!!!!!
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: 1.000000!!!!!!!!
# ep 956: game finished, reward: -1.000000
# ep 956: game finished, reward: 1.000000!!!!!!!!
# ep 956: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.953159
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: 1.000000!!!!!!!!
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: 1.000000!!!!!!!!
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: 1.000000!!!!!!!!
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: 1.000000!!!!!!!!
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# ep 957: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.953627
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: 1.000000!!!!!!!!
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: 1.000000!!!!!!!!
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: 1.000000!!!!!!!!
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: 1.000000!!!!!!!!
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: 1.000000!!!!!!!!
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: 1.000000!!!!!!!!
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: 1.000000!!!!!!!!
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# ep 958: game finished, reward: -1.000000
# resetting env. episode reward total was -14.000000. running mean: -16.924091
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: 1.000000!!!!!!!!
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: 1.000000!!!!!!!!
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: 1.000000!!!!!!!!
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# ep 959: game finished, reward: -1.000000
# resetting env. episode reward total was -18.000000. running mean: -16.934850
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: 1.000000!!!!!!!!
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: 1.000000!!!!!!!!
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: 1.000000!!!!!!!!
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: 1.000000!!!!!!!!
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: 1.000000!!!!!!!!
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: -1.000000
# ep 960: game finished, reward: 1.000000!!!!!!!!
# ep 960: game finished, reward: -1.000000
# resetting env. episode reward total was -15.000000. running mean: -16.915502
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: 1.000000!!!!!!!!
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: 1.000000!!!!!!!!
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: 1.000000!!!!!!!!
# ep 961: game finished, reward: 1.000000!!!!!!!!
# ep 961: game finished, reward: 1.000000!!!!!!!!
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: 1.000000!!!!!!!!
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: 1.000000!!!!!!!!
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: 1.000000!!!!!!!!
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# ep 961: game finished, reward: -1.000000
# resetting env. episode reward total was -13.000000. running mean: -16.876347
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: 1.000000!!!!!!!!
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: 1.000000!!!!!!!!
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: 1.000000!!!!!!!!
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: 1.000000!!!!!!!!
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: 1.000000!!!!!!!!
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: -1.000000
# ep 962: game finished, reward: 1.000000!!!!!!!!
# ep 962: game finished, reward: -1.000000
# resetting env. episode reward total was -15.000000. running mean: -16.857583
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: 1.000000!!!!!!!!
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: 1.000000!!!!!!!!
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: 1.000000!!!!!!!!
# ep 963: game finished, reward: 1.000000!!!!!!!!
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: 1.000000!!!!!!!!
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: 1.000000!!!!!!!!
# ep 963: game finished, reward: 1.000000!!!!!!!!
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: 1.000000!!!!!!!!
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: 1.000000!!!!!!!!
# ep 963: game finished, reward: -1.000000
# ep 963: game finished, reward: -1.000000
# resetting env. episode reward total was -12.000000. running mean: -16.809007
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: 1.000000!!!!!!!!
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: 1.000000!!!!!!!!
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: 1.000000!!!!!!!!
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: 1.000000!!!!!!!!
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# ep 964: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.810917
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: 1.000000!!!!!!!!
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: 1.000000!!!!!!!!
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: 1.000000!!!!!!!!
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: 1.000000!!!!!!!!
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: 1.000000!!!!!!!!
# ep 965: game finished, reward: -1.000000
# ep 965: game finished, reward: -1.000000
# resetting env. episode reward total was -16.000000. running mean: -16.802808
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: 1.000000!!!!!!!!
# ep 966: game finished, reward: 1.000000!!!!!!!!
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: 1.000000!!!!!!!!
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: 1.000000!!!!!!!!
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: 1.000000!!!!!!!!
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: 1.000000!!!!!!!!
# ep 966: game finished, reward: -1.000000
# ep 966: game finished, reward: -1.000000
# resetting env. episode reward total was -15.000000. running mean: -16.784780
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: 1.000000!!!!!!!!
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: 1.000000!!!!!!!!
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: 1.000000!!!!!!!!
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: 1.000000!!!!!!!!
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: 1.000000!!!!!!!!
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: -1.000000
# ep 967: game finished, reward: 1.000000!!!!!!!!
# ep 967: game finished, reward: -1.000000
# resetting env. episode reward total was -15.000000. running mean: -16.766932
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: 1.000000!!!!!!!!
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: -1.000000
# ep 968: game finished, reward: 1.000000!!!!!!!!
# ep 968: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -16.789263
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: 1.000000!!!!!!!!
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: 1.000000!!!!!!!!
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: 1.000000!!!!!!!!
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: 1.000000!!!!!!!!
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: 1.000000!!!!!!!!
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: 1.000000!!!!!!!!
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: -1.000000
# ep 969: game finished, reward: 1.000000!!!!!!!!
# ep 969: game finished, reward: -1.000000
# resetting env. episode reward total was -14.000000. running mean: -16.761370
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: 1.000000!!!!!!!!
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: 1.000000!!!!!!!!
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: 1.000000!!!!!!!!
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: -1.000000
# ep 970: game finished, reward: 1.000000!!!!!!!!
# ep 970: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.763757
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: 1.000000!!!!!!!!
# ep 971: game finished, reward: 1.000000!!!!!!!!
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: 1.000000!!!!!!!!
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: 1.000000!!!!!!!!
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: 1.000000!!!!!!!!
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: 1.000000!!!!!!!!
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# ep 971: game finished, reward: -1.000000
# resetting env. episode reward total was -15.000000. running mean: -16.746119
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: 1.000000!!!!!!!!
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: 1.000000!!!!!!!!
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: 1.000000!!!!!!!!
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: 1.000000!!!!!!!!
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: 1.000000!!!!!!!!
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: 1.000000!!!!!!!!
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: 1.000000!!!!!!!!
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: 1.000000!!!!!!!!
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# ep 972: game finished, reward: -1.000000
# resetting env. episode reward total was -13.000000. running mean: -16.708658
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: 1.000000!!!!!!!!
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: 1.000000!!!!!!!!
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# ep 973: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -16.731571
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: 1.000000!!!!!!!!
# ep 974: game finished, reward: 1.000000!!!!!!!!
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# ep 974: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -16.754256
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: 1.000000!!!!!!!!
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: 1.000000!!!!!!!!
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: 1.000000!!!!!!!!
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: 1.000000!!!!!!!!
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: 1.000000!!!!!!!!
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: 1.000000!!!!!!!!
# ep 975: game finished, reward: -1.000000
# ep 975: game finished, reward: -1.000000
# resetting env. episode reward total was -15.000000. running mean: -16.736713
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: 1.000000!!!!!!!!
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: 1.000000!!!!!!!!
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# ep 976: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -16.759346
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: 1.000000!!!!!!!!
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: 1.000000!!!!!!!!
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: 1.000000!!!!!!!!
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: 1.000000!!!!!!!!
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# ep 977: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.761752
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: 1.000000!!!!!!!!
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: 1.000000!!!!!!!!
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: 1.000000!!!!!!!!
# ep 978: game finished, reward: -1.000000
# ep 978: game finished, reward: 1.000000!!!!!!!!
# ep 978: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.764135
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: 1.000000!!!!!!!!
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: 1.000000!!!!!!!!
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: 1.000000!!!!!!!!
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: 1.000000!!!!!!!!
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# ep 979: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.766494
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: 1.000000!!!!!!!!
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: 1.000000!!!!!!!!
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# ep 980: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -16.788829
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: 1.000000!!!!!!!!
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# ep 981: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -16.820940
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: 1.000000!!!!!!!!
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: 1.000000!!!!!!!!
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# ep 982: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -16.842731
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# ep 983: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -16.884304
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: 1.000000!!!!!!!!
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: 1.000000!!!!!!!!
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: 1.000000!!!!!!!!
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: 1.000000!!!!!!!!
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: 1.000000!!!!!!!!
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: 1.000000!!!!!!!!
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: 1.000000!!!!!!!!
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# ep 984: game finished, reward: -1.000000
# resetting env. episode reward total was -14.000000. running mean: -16.855461
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: 1.000000!!!!!!!!
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: 1.000000!!!!!!!!
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: 1.000000!!!!!!!!
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: 1.000000!!!!!!!!
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: 1.000000!!!!!!!!
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: 1.000000!!!!!!!!
# ep 985: game finished, reward: -1.000000
# ep 985: game finished, reward: 1.000000!!!!!!!!
# ep 985: game finished, reward: -1.000000
# resetting env. episode reward total was -14.000000. running mean: -16.826906
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: 1.000000!!!!!!!!
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: 1.000000!!!!!!!!
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: 1.000000!!!!!!!!
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: -1.000000
# ep 986: game finished, reward: 1.000000!!!!!!!!
# ep 986: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.828637
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: 1.000000!!!!!!!!
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: 1.000000!!!!!!!!
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: 1.000000!!!!!!!!
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: 1.000000!!!!!!!!
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: 1.000000!!!!!!!!
# ep 987: game finished, reward: -1.000000
# ep 987: game finished, reward: 1.000000!!!!!!!!
# ep 987: game finished, reward: -1.000000
# resetting env. episode reward total was -15.000000. running mean: -16.810351
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: 1.000000!!!!!!!!
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: 1.000000!!!!!!!!
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: 1.000000!!!!!!!!
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: 1.000000!!!!!!!!
# ep 988: game finished, reward: -1.000000
# ep 988: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.812247
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: 1.000000!!!!!!!!
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: 1.000000!!!!!!!!
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: 1.000000!!!!!!!!
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: 1.000000!!!!!!!!
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: 1.000000!!!!!!!!
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: 1.000000!!!!!!!!
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: 1.000000!!!!!!!!
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# ep 989: game finished, reward: -1.000000
# resetting env. episode reward total was -14.000000. running mean: -16.784125
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: 1.000000!!!!!!!!
# ep 990: game finished, reward: 1.000000!!!!!!!!
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: 1.000000!!!!!!!!
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# ep 990: game finished, reward: -1.000000
# resetting env. episode reward total was -18.000000. running mean: -16.796283
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: 1.000000!!!!!!!!
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: 1.000000!!!!!!!!
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: 1.000000!!!!!!!!
# ep 991: game finished, reward: -1.000000
# ep 991: game finished, reward: -1.000000
# resetting env. episode reward total was -18.000000. running mean: -16.808321
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: 1.000000!!!!!!!!
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: 1.000000!!!!!!!!
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: 1.000000!!!!!!!!
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: 1.000000!!!!!!!!
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# ep 992: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.810237
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: 1.000000!!!!!!!!
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: 1.000000!!!!!!!!
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: 1.000000!!!!!!!!
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: 1.000000!!!!!!!!
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# ep 993: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.812135
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: 1.000000!!!!!!!!
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: 1.000000!!!!!!!!
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: 1.000000!!!!!!!!
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: 1.000000!!!!!!!!
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: 1.000000!!!!!!!!
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: 1.000000!!!!!!!!
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: 1.000000!!!!!!!!
# ep 994: game finished, reward: -1.000000
# ep 994: game finished, reward: 1.000000!!!!!!!!
# ep 994: game finished, reward: -1.000000
# resetting env. episode reward total was -13.000000. running mean: -16.774014
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: 1.000000!!!!!!!!
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: 1.000000!!!!!!!!
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# ep 995: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -16.796273
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: 1.000000!!!!!!!!
# ep 996: game finished, reward: 1.000000!!!!!!!!
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: 1.000000!!!!!!!!
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: 1.000000!!!!!!!!
# ep 996: game finished, reward: -1.000000
# ep 996: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.798311
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: 1.000000!!!!!!!!
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: 1.000000!!!!!!!!
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: 1.000000!!!!!!!!
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: 1.000000!!!!!!!!
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: 1.000000!!!!!!!!
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# ep 997: game finished, reward: -1.000000
# resetting env. episode reward total was -16.000000. running mean: -16.790328
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: 1.000000!!!!!!!!
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: 1.000000!!!!!!!!
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: 1.000000!!!!!!!!
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: 1.000000!!!!!!!!
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: 1.000000!!!!!!!!
# ep 998: game finished, reward: 1.000000!!!!!!!!
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: -1.000000
# ep 998: game finished, reward: 1.000000!!!!!!!!
# ep 998: game finished, reward: -1.000000
# resetting env. episode reward total was -14.000000. running mean: -16.762424
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: 1.000000!!!!!!!!
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: 1.000000!!!!!!!!
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: 1.000000!!!!!!!!
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: 1.000000!!!!!!!!
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# ep 999: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -16.764800
# ep 1000: game finished, reward: 1.000000!!!!!!!!
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: 1.000000!!!!!!!!
# ep 1000: game finished, reward: 1.000000!!!!!!!!
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: 1.000000!!!!!!!!
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: 1.000000!!!!!!!!
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# ep 1000: game finished, reward: -1.000000
# resetting env. episode reward total was -16.000000. running mean: -16.757152
# ep 1001: game finished, reward: -1.000000
# ep 1001: game finished, reward: -1.000000
# ep 1001: game finished, reward: 1.000000!!!!!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-19abaed2ca16> in <module>
#      18
#      19   # forward the policy network and sample an action from the returned probability
# ---> 20   aprob, h = policy_forward(x)
#      21   # The following step is randomly choosing a number which is the basis of making an action decision
#      22   # If the random number is less than the probability of UP output from our neural network given the image
#
# <ipython-input-13-adda0ddaba47> in policy_forward(x)
#      24 def policy_forward(x):
#      25   """This is a manual implementation of a forward prop"""
# ---> 26   h = np.dot(model['W1'], x) # (H x D) . (D x 1) = (H x 1) (200 x 1)
#      27   h[h<0] = 0 # ReLU introduces non-linearity
#      28   logp = np.dot(model['W2'], h) # This is a logits function and outputs a decimal.   (1 x H) . (H x 1) = 1 (scalar)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ---
#
# **DISCUSSION**
#
# ---
#
# The program develops an AI Agent to play Pong, utilizing Reinforced Learning to improve every episode. In this program, the AI and its opponent play a game of Pong with a race-to-21 mechanic. Points given to the reinforced AI is treated as the "reward" to encourage the leaning towards the positive outcome. Image Processing of the Pong playing field is utilized to determine paddle position and current number state to act as the input for learning.
#
# For every episode finished, a rendered .mp4 video file is saved. The point differential in scoring per episode is shown.
#
# Current trend suggest an improvement is evident in the agent as the running mean gets lower and lower, more episodes of learning would eventually push the agent to overcome the point differential, reach 21 points first and beat the enemy.
#
#
#
# Sources:
#
# https://towardsdatascience.com/intro-to-reinforcement-learning-pong-92a94aa0f84d
#
# https://github.com/omkarv/pong-from-pixels
